# %%
import pandas as pd                                                           # For dataframes
import numpy as np                                                            # For various functions
import matplotlib.pyplot as plt                                               # For plotting functions
import seaborn as sns                                                         # For additional plotting functions
from sklearn.model_selection import train_test_split                         # For train/test splits

# %%
#https://archive.ics.uci.edu/dataset/80/optical+recognition+of+handwritten+digits

# %%
df = pd.read_csv("optdigits.csv")

df.head()

df.tail()
# Out:
#       0  1  6  15  12  1.1  0.1  0.2  0.3  7  ...  0.21  0.22  0.23  6.3  \
# 3817  0  0  5  13  11    2    0    0    0  2  ...     0     0     0    8
# 3818  0  0  0   1  12    1    0    0    0  0  ...     0     0     0    0
# 3819  0  0  3  15   0    0    0    0    0  0  ...     0     0     0    4
# 3820  0  0  6  16   2    0    0    0    0  0  ...     0     0     0    5
# 3821  0  0  2  15  16   13    1    0    0  0  ...     0     0     0    4
#
#       14.1  7.4  1.3  0.24  0.25  0.26
# 3817    13   15   10     1     0     9
# 3818     4    9    0     0     0     4
# 3819    14   16    9     0     0     6
# 3820    16   16   16     5     0     6
# 3821    14    1    0     0     0     7
#
# [5 rows x 65 columns]

# %%
#Sequetially rename all attribute columns (i.e. pixel data) as P0, P2, etc - Renames the class variable as y


df.columns = ["P" + str(i) for i in range(0, len(df.columns) - 1)] +["y"]

# %%
df.head()
# Out:
#    P0  P1  P2  P3  P4  P5  P6  P7  P8  P9  ...  P55  P56  P57  P58  P59  P60  \
# 0   0   0  10  16   6   0   0   0   0   7  ...    0    0    0   10   16   15
# 1   0   0   8  15  16  13   0   0   0   1  ...    0    0    0    9   14    0
# 2   0   0   0   3  11  16   0   0   0   0  ...    0    0    0    0    1   15
# 3   0   0   5  14   4   0   0   0   0   0  ...    0    0    0    4   12   14
# 4   0   0  11  16  10   1   0   0   0   4  ...    3    0    0   10   16   16
#
#    P61  P62  P63  y
# 0    3    0    0  0
# 1    0    0    0  7
# 2    2    0    0  4
# 3    7    0    0  6
# 4   16   16    6  2
#
# [5 rows x 65 columns]

# %%
df = df.loc[df.y.isin([1,3,6])]

df.head()
# Out:
#     P0  P1  P2  P3  P4  P5  P6  P7  P8  P9  ...  P55  P56  P57  P58  P59  P60  \
# 3    0   0   5  14   4   0   0   0   0   0  ...    0    0    0    4   12   14
# 10   0   0   0   3  16  11   1   0   0   0  ...    0    0    0    0    2   14
# 13   0   0   7  11  11   6   0   0   0   9  ...    0    0    0   14   16   12
# 23   0   0   9  13   1   0   0   0   0   0  ...    5    0    0    4   15   16
# 26   0   0   0  10  12   0   0   0   0   0  ...    0    0    0    1   11   14
#
#     P61  P62  P63  y
# 3     7    0    0  6
# 10   14    1    0  1
# 13   10    1    0  3
# 23   16   16   16  1
# 26   12    1    0  6
#
# [5 rows x 65 columns]

# %%
X_trn, X_tst, y_trn, y_tst = train_test_split(df.filter(regex='\d'), df.y, test_size=0.3, random_state=1)

trn = X_trn
trn["y"] = y_trn

tst = X_tst
tst["y"] = y_tst

# %%
fig, ax = plt.subplots(nrows=1, ncols=20, figsize=(15, 3.5), subplot_kw=dict(xticks=[], yticks=[]))

for i in np.arange(20):
    ax[i].imshow(X_trn.to_numpy()[i, 0:-1].reshape(8,8), cmap=plt.cm.gray)
plt.show()
